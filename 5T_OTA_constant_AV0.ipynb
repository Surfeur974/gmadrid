# %%
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
from pygmid import Lookup as lk
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
pmos4 = lk('lookup_table/pmos4.mat')
nmos4 = lk('lookup_table/nmos4.mat')
# Interpolation function
def interp1(x, y, value):
    # Perform cubic interpolation using interp1d
    f = interp1d(x, y, kind='cubic')
    return f(value)

# %% [markdown]
# 5T OTA
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# Sizing at constant gain, for 1 max frequency, 2 min current for max frequency*0.8

# %%
#Specification
AV_spec = 100
CL = 1e-12
VDD = 2.7
V_IC = 1.35

# %%
#Hypothèse : L et GM
#L1 = L2
#Sizing at constant gain, for 
# 1) max frequency
# 2) min current for max frequency*0.8

# %%
#Plot of AV0 and FT versus gm/id
Npoint = 20
gmid_test = np.linspace(1.0,25.0,Npoint)
#L_test = nmos4['L']
L_test = np.linspace(.35,10.0,Npoint)

#AV0 = gmID1 / (gdsID1 + gdsID2)
#FU = gm1/(2*3.14159*CL)
gdsID1 = nmos4.lookup('GDS_ID', GM_ID=gmid_test, L=L_test)
gdsID2 = pmos4.lookup('GDS_ID', GM_ID=gmid_test, L=L_test)

fT = nmos4.lookup('GM_CGG', GM_ID=gmid_test, L=L_test) /(2*3.14159) * 1e-9
AV0 = gmid_test / (gdsID1 + gdsID2)
#AV0 = nmos4.lookup('GM_GDS', GM_ID=gmid_test, L=L_test)


fig, ax1 = plt.subplots()
ax1.semilogy(gmid_test, fT.transpose())
plt.xlabel('$g_m/I_D$ (S/A)')
plt.ylabel(r'$f_T$ (GHz)')
ax2 = ax1.twinx()
ax2.semilogy(gmid_test, AV0.transpose(),linestyle='--')
plt.ylabel(r'$AV_0/$ (V/V)')
#ax1.legend(loc='center right', bbox_to_anchor=(1.3, 0.5), title='L', labels=L_test.tolist())
plt.axhline(y=AV_spec, color='k', linestyle='solid')


plt.show()

# %%
#Plot of GM_ID and FT for each L where AV0 == AV_spec
# On veut les valeur gmID et FT pour lesquel AV0 = AVREF
gmID1 = np.zeros(L_test.size)
ft1 = np.zeros(L_test.size)
for k in range(len(L_test)):
    gmID1[k] = interp1(AV0[k], gmid_test, AV_spec)
    ft1[k] = interp1(gmid_test, fT[k], gmID1[k])

plt.plot(L_test, gmID1,marker='o', markersize=5, markeredgewidth=2, linestyle='--', color='gray')
plt.xlabel('$L$ (um)')
plt.ylabel(r'$GM_ID/$')
plt.twinx()
plt.plot(L_test, ft1,marker='o', markersize=5, markeredgewidth=2, linestyle='--', color='red')
plt.ylabel(r'$f_T$ (GHz)')


#plt.show()

L_for_FTMAX = L_test[np.argmax(ft1)]
gmID_for_FTMAX = gmID1[np.argmax(ft1)]
FT_MAX = max(ft1)

print("Pour un gain de ", AV_spec)
print("La FT_max est de GHz", FT_MAX)
print("Pour la FT maximum, il faut L = : ", L_for_FTMAX)
print("Pour la FT maximum, il faut gmid = : ", gmID_for_FTMAX)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[204], line 6
#       2 # On veut les valeur gmID et FT pour lesquel AV0 = AVREF
#       3 gmID1 = np.zeros(L_test.size)
#       4 ft1 = np.zeros(L_test.size)
#       5 for k in range(len(L_test)):
# ----> 6     gmID1[k] = interp1(AV0[k], gmid_test, AV_spec)
#       7     ft1[k] = interp1(gmid_test, fT[k], gmID1[k])
#       8
#       9 plt.plot(L_test, gmID1,marker='o', markersize=5, markeredgewidth=2, linestyle='--', color='gray')
#
# Cell In[200], line 13, in interp1(x, y, value)
#      10 def interp1(x, y, value):
#      11     # Perform cubic interpolation using interp1d
#      12     f = interp1d(x, y, kind='cubic',bounds_error='true')
# ---> 13     return f(value)
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\scipy\interpolate\_polyint.py:86, in _Interpolator1D.__call__(self, x)
#      65 """
#      66 Evaluate the interpolant
#      67
#    (...)     83
#      84 """
#      85 x, x_shape = self._prepare_x(x)
# ---> 86 y = self._evaluate(x)
#      87 return self._finish_y(y, x_shape)
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\scipy\interpolate\_interpolate.py:555, in interp1d._evaluate(self, x_new)
#     553 y_new = self._call(self, x_new)
#     554 if not self._extrapolate:
# --> 555     below_bounds, above_bounds = self._check_bounds(x_new)
#     556     if len(y_new) > 0:
#     557         # Note fill_value must be broadcast up to the proper size
#     558         # and flattened to work here
#     559         y_new[below_bounds] = self._fill_value_below
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\scipy\interpolate\_interpolate.py:588, in interp1d._check_bounds(self, x_new)
#     586 if self.bounds_error and above_bounds.any():
#     587     above_bounds_value = x_new[np.argmax(above_bounds)]
# --> 588     raise ValueError(f"A value ({above_bounds_value}) in x_new is above "
#     589                      f"the interpolation range's maximum value ({self.x[-1]}).")
#     591 # !! Should we emit a warning if some values are out of bounds?
#     592 # !! matlab does not.
#     593 return below_bounds, above_bounds
#
# ValueError: A value (100.0) in x_new is above the interpolation range's maximum value (26.54011751572504).

# %%
L12 = L_for_FTMAX
gmID_for_FTMAX = gmID_for_FTMAX * 1
gmID1 = gmID_for_FTMAX
gmID2 = gmID_for_FTMAX
FU = FT_MAX *1e9
FU = 100e3


CselfLoading = 0

#gm and ID, from Spec and Hypothesis
gm1 = 2*3.14159*FU*CL
ID = gm1 / gmID1
#VGS from lookupVGS, L and GM_ID
# Find VDS1 and 
VGS1 = nmos4.lookupVGS(GM_ID=gmID1, L=L12, VDS=0.6, VSB=0) #Fist estimation with vds default
VGS2 = pmos4.lookupVGS(GM_ID=gmID2, L=L12, VDS=0.6, VSB=0) #Fist estimation with vds default
VGS2 = pmos4.lookupVGS(GM_ID=gmID2, L=L12, VDS=VGS2, VSB=0) #Second with VDS = VGS (current mirror)
VS = V_IC - VGS1
VD = VDD - VGS2
VDS1 = VD - VS
VGS1 = nmos4.lookupVGS(GM_ID=gmID1, L=L12, VDS=VDS1, VSB=0) #Second with VDS
##Design terminé##

#Calcul Gain
gdsID1 = nmos4.look_up('GDS_ID', GM_ID=gmID1, VDS=VDS1, L=L12, VSB=0)
gdsID2 = pmos4.look_up('GDS_ID', GM_ID=gmID2, VDS=VDS1, L=L12, VSB=0)
AV0 = gmID1 / (gdsID1 + gdsID2)

print('AV0 = %.2F' % AV0)
print('gm1 = %.2F uS' % (gm1 * 1e6))
print('VDS1 = %.2F' % VDS1)


for m in range(1,10,1):
    #self loading
    gm1 = 2*3.14159*FU*(CL+CselfLoading)
    ID = gm1 / gmID1
    #Denormalization
    JD1 = nmos4.lookup('ID_W', GM_ID=gmID1, VDS=VDS1, L=L12, VSB=0)
    JD2 = pmos4.lookup('ID_W', GM_ID=gmID2, VDS=VGS2, L=L12, VSB=0)
    W1 = ID/JD1
    W2 = ID/JD2
    print('ID = %.2F uA' % (ID* 1e6))
    print('W1 = %.2F um' % (W1))
    print('W2 = %.2F um' % (W2))
    CDD1 = W1 * nmos4.look_up('CDD_W', GM_ID=gmID1, L=L12, VSB=0)
    CDD2 = W2 * pmos4.look_up('CDD_W', GM_ID=gmID2, L=L12, VSB=0)
    CselfLoading = CDD1 + CDD2
# Out:
# look_upVGS: GM_ID input larger than maximum!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 18
#      14 #VGS from lookupVGS, L and GM_ID
#      15 # Find VDS1 and
#      16 VGS1 = nmos4.lookupVGS(GM_ID=gmID1, L=L12, VDS=0.6, VSB=0) #Fist estimation with vds default
#      17 VGS2 = pmos4.lookupVGS(GM_ID=gmID2, L=L12, VDS=0.6, VSB=0) #Fist estimation with vds default
# ---> 18 VGS2 = pmos4.lookupVGS(GM_ID=gmID2, L=L12, VDS=VGS2, VSB=0) #Second with VDS = VGS (current mirror)
#      19 VS = V_IC - VGS1
#      20 VD = VDD - VGS2
#      21 VDS1 = VD - VS
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\pygmid\Lookup.py:290, in Lookup.lookupVGS(self, **kwargs)
#     289 def lookupVGS(self, **kwargs):
# --> 290     return self.look_upVGS(**kwargs)
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\pygmid\Lookup.py:377, in Lookup.look_upVGS(self, **kwargs)
#     374         if max(np.atleast_1d(ratio_data)) > m:
#     375             print('look_upVGS: GM_ID input larger than maximum!')
# --> 377     output[j,:] = interp1(ratio_range, VGS_range)(ratio_data)
#     378     output = output[:]
#     380 return np.squeeze(output)
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\pygmid\numerical.py:39, in interp1(x, y, **ipkwargs)
#      36     x = x[ind]
#      37     y = np.take(y, ind, axis=-1)
# ---> 39     return PchipInterpolator(x, y, **pchipkwargs)
#      40 else:
#      41     return interp1d(x, y, **ipkwargs)
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\scipy\interpolate\_cubic.py:263, in PchipInterpolator.__init__(self, x, y, axis, extrapolate)
#     261 def __init__(self, x, y, axis=0, extrapolate=None):
#     262     xp = array_namespace(x, y)
# --> 263     x, _, y, axis, _ = prepare_input(x, y, axis, xp=xp)
#     264     if xp.isdtype(y.dtype, "complex floating"):
#     265         msg = ("`PchipInterpolator` only works with real values for `y`. "
#     266                "If you are trying to use the real components of the passed array, "
#     267                "use `np.real` on the array before passing to `PchipInterpolator`.")
#
# File c:\Users\Surfe\Desktop\gmoverid_repos\gmadrid\.venv\Lib\site-packages\scipy\interpolate\_cubic.py:50, in prepare_input(x, y, axis, dydx, xp)
#      48     raise ValueError("`x` must be 1-dimensional.")
#      49 if x.shape[0] < 2:
# ---> 50     raise ValueError("`x` must contain at least 2 elements.")
#      51 if x.shape[0] != y.shape[axis]:
#      52     raise ValueError(f"The length of `y` along `axis`={axis} doesn't "
#      53                      "match the length of `x`")
#
# ValueError: `x` must contain at least 2 elements.

# %%
print('AV0 = %.2F dB' % (20*np.log10(AV0)))
print('AV0 = %.2F V/V' % (AV0))
print('gm1 = %.2F uS' % (gm1 * 1e6))    
print('ID = %.2F uA' % (ID* 1e6))
print('W1 = %.2F um' % (W1))
print('W2 = %.2F um' % (W2))
print('L1 = %.2F um' % (L12))
print('L2 = %.2F um' % (L12))
# Out:
# AV0 = 39.06 dB
# AV0 = 89.72 V/V
# gm1 = 0.63 uS
# ID = 0.10 uA
# W1 = 0.02 um
# W2 = 0.05 um
# L1 = 1.00 um
# L2 = 1.00 um
